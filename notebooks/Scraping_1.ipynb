# %%
import pandas as pd
import requests
from nltk.corpus import stopwords
from bs4 import BeautifulSoup
import re

# %%
data = pd.read_csv("CSVData.csv", header=None)
data.columns = ["date", "amount", "description", "balance"]
data['date']  = pd.to_datetime(data['date'], format='%d/%m/%Y')
data = data.drop("balance", axis=1)
data = data.astype({'amount':'float'})
data.description = data.description.str.strip()
data.description = data.description.str.lower()

# %%
blacklist = stopwords.words('english')
blacklist += ['card', 'aus', 'au', 'ns', 'nsw', 'xx']

def clean(string):
    features = ""
    out = string
    if "value date: " in out:
        out = out.split("value date: ")[0]
    out = re.sub(r'([^a-z ]+)', " ", out) # remove non-alphabetic characters
    for word in out.strip().split(" "):
        if word not in blacklist and len(word) > 1 and " " + word + " " not in features: # ensuring no duplicates
            features += word + " "
    return features.strip()

data["desc_features"] = [clean(desc) for desc in data.description]
data
# Out:
#           date  amount                                        description  \
# 0   2020-07-10   -6.99  hfm boronia park         boronia park au card ...
# 1   2020-07-10   -8.40           charlotte cafe           gladesville  au
# 2   2020-07-08  -12.00  glen garry castle ho     redfern      au card ...
# 3   2020-07-08  -12.00  glen garry castle ho     redfern      au card ...
# 4   2020-07-08   15.00  transfer from mr tryone kenhong jabez ja credi...
# ..         ...     ...                                                ...
# 595 2019-09-04  -17.00  mr yeeros newtown flinders view ns aus card xx...
# 596 2019-09-04  -12.99  7-eleven 2118 camperdown ns aus card xx6725 va...
# 597 2019-09-04   -2.50  coles express 1544 drummoyne au aus card xx672...
# 598 2019-09-03   -8.99           qe foodstores            camperdown   au
# 599 2019-09-03   -1.00  7-eleven 2118 camperdown ns aus card xx6725 va...
#
#                                          desc_features
# 0                                     hfm boronia park
# 1                           charlotte cafe gladesville
# 2                         glen garry castle ho redfern
# 3                         glen garry castle ho redfern
# 4    transfer mr tryone kenhong jabez ja credit acc...
# ..                                                 ...
# 595                    mr yeeros newtown flinders view
# 596                                  eleven camperdown
# 597                            coles express drummoyne
# 598                           qe foodstores camperdown
# 599                                  eleven camperdown
#
# [600 rows x 4 columns]

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

def google(query):
    req = requests.get("https://www.google.com/search?q="+query, headers=headers)
    req.raise_for_status()
    soup = BeautifulSoup(req.text, "html.parser")
    cat = soup.find_all("span", class_="YhemCb")
    if len(cat) > 0:
        cat = str(cat[-1])
        cat = cat.split(">")[1].split("<")[0]
        if " in " in cat:
            cat = cat.split(" in ")[0]
        print(query, cat)
        return cat
    else:
        print(query)
        return None

    

data["google"] = [google(query) for query in data.desc_features]
data
# Out:
# hfm boronia park Farmers' market
# charlotte cafe gladesville Cafe
# glen garry castle ho redfern Pub
# glen garry castle ho redfern Pub
# transfer mr tryone kenhong jabez ja credit account
# dymocks lane cove Book store
# sq wok passion lane cove Asian restaurant
# transfer mr tryone kenhong jabez ja credit account
# pharmacy less ryde Drug store
# function pcp gladesville Physiotherapist
# transportfornsw opal chippendale
# werri beach fish shop werri Fish and chips takeaway
# transfer catharine dodds commbank app scripts
# transfer mrs helen andrea dodds credit account
# hfm boronia park Farmers' market
# newsxpress gerringong Newsstand
# willoughby city counci chatswood
# apple online sydney
# hungry jacks haywards bay Fast food restaurant
# mosman iga mosman
# transfer miss charlotte alice mcgui credit account
# dan murphys mosman Bottle Shop and Liquor Store
# mosman iga mosman
# mcdonalds stanmore nswau Fast food restaurant
# eleven camperdown
# supamart harold park forest lodge Grocery store
# taste baguette universit Cafe
# chippendale cellars chippendale Bottle Shop and Liquor Store
# mr yeeros newtown flinders view Fast food restaurant
# uber trip sydney
# transfer commbank app johns bond
# direct credit st john colleg college
# transfer mcguirec credit account
# mcdonalds stanmore nswau Fast food restaurant
# transfer bank commbank app king st
# transfer commbank app
# transfer alison voulgaris tutoring max
# eleven camperdown
# transfer commbank app
# regent hotel kingsford Pub
# regent hotel kingsford Pub
# regent hotel kingsford Pub
# direct credit nab transfer angus houston
# taste baguette universit Cafe
# eleven camperdown
# eleven camperdown
# eleven camperdown
# sq dail camperdown
# qe foodstores camperdown Convenience store
# grounded cafe camperdown Cafe
# alfred hotel mngmnt camperdown Pub
# alfred hotel mngmnt camperdown Pub
# restaurant darlington
# osaka trading co forest lodge Japanese restaurant
# eleven camperdown
# taste baguette universit Cafe
# mcdonalds stanmore nswau Fast food restaurant
# eleven camperdown
# eleven camperdown
# transfer bank commbank app hey
# ralph cafe universit
# eleven camperdown
# freda chippendale Bar
# coles express drummoyne
# uber trip sydney
# alfred hotel mngmnt camperdown Pub
# taste baguette universit Cafe
# taste baguette universit Cafe
# ralph cafe universit
# franks pizza bar camperdown Pizza restaurant
# sq dail camperdown
# sq dail camperdown
# uberuae eats sydney
# eleven camperdown
# uberuae eats sydney
# grounded cafe camperdown Cafe
# coles express hunters hill Convenience store
# eastern suburbs dist bellevue hill
# eastern suburbs dist bellevue hill
# eastern suburbs dist bellevue hill
# transportfornsw opal chippendale
# uberuae eats sydney
# uberuae eats sydney
# eleven camperdown
# eleven camperdown
# uber trip sydney
# grounded cafe camperdown Cafe
# grounded cafe camperdown Cafe
# debit excess interest
# ralph cafe universit
# delish pork pl newtown Take Away Restaurant
# transfer anne marie brown tutoring maths
# eleven camperdown
# eleven camperdown
# alfred hotel mngmnt camperdown Pub
# uberuae eats sydney
# taste baguette universit Cafe
# mcdonalds stanmore nswau Fast food restaurant
# eleven camperdown
# eleven camperdown
# eleven camperdown
# uber eats sydney
# uber eats sydney
# uber eats sydney
# officeworks glebe Office supply store
# officeworks glebe Office supply store
# coles express drummoyne
# mcdonalds stanmore nswau Fast food restaurant
# direct credit anne marie brown billy dodds
# eleven camperdown
# taste baguette sydney
# mcdonalds darling qtr sydney nswau Fast food restaurant
# coles express drummoyne
# transfer bank commbank app hey
# commbank app tfr rachel dodds chopper
# transfer catharine dodds commbank app mum
# dental corporation gladesville Business to business service
# alfred hotel mngmnt camperdown Pub
# alfred hotel mngmnt camperdown Pub
# mr yeeros newtown flinders view Fast food restaurant
# eleven camperdown
# franks pizza bar camperdown Pizza restaurant
# eleven camperdown
# alfred hotel mngmnt camperdown Pub
# sq dail camperdown
# sq dail camperdown
# transfer cassidy lobb commbank app alcohol
# mcdonaldscamperdownca camperdown nswau
# reject shop glebe Department store
# sq dail camperdown
# taste baguette sydney
# uber trip sydney
# liquorland glebe Bottle Shop and Liquor Store
# uberuae eats sydney
# eastern suburbs dist bellevue hill
# return uberuae eats sydney
# mcdonaldscamperdownca camperdown nswau
# qpay parammatta Financial institution
# uber trip sydney
# uber trip sydney
# coles express drummoyne
# qpay parammatta Financial institution
# gin lane chippendale Cocktail bar
# kopi tiam spice alley chippendale Food court
# salary st john colleg johns college
# coles express drummoyne
# uber trip help uber co
# uber trip help uber co
# uber trip help uber co
# uber trip help uber co
# paragon sydney Pub
# paragon sydney Pub
# iwannaticket darlinghurst Event ticket seller
# transfer commbank app
# commbank app tfr rachel dodds chopper
# mcdonaldscamperdownca camperdown nswau
# mcdonalds gladesville nswau Fast food restaurant
# transfer mcguirec credit account
# eleven camperdown
# paypal tobydeals
# bondi junction store bondi junctioau
# transfer commbank app
# bellevue hotel paddington Pub
# express mart pty ltd paddington
# coogee ground coogee
# eleven camperdown
# mcdonalds darling qtr sydney nswau Fast food restaurant
# mcdonaldscamperdownca camperdown nswau
# eleven camperdown
# transfer commbank app
# mr yeeros newtown flinders view Fast food restaurant
# eleven camperdown
# coles express drummoyne
# qe foodstores camperdown Convenience store
# eleven camperdown
#           date  amount                                        description  \
# 0   2020-07-10   -6.99  hfm boronia park         boronia park au card ...
# 1   2020-07-10   -8.40           charlotte cafe           gladesville  au
# 2   2020-07-08  -12.00  glen garry castle ho     redfern      au card ...
# 3   2020-07-08  -12.00  glen garry castle ho     redfern      au card ...
# 4   2020-07-08   15.00  transfer from mr tryone kenhong jabez ja credi...
# ..         ...     ...                                                ...
# 595 2019-09-04  -17.00  mr yeeros newtown flinders view ns aus card xx...
# 596 2019-09-04  -12.99  7-eleven 2118 camperdown ns aus card xx6725 va...
# 597 2019-09-04   -2.50  coles express 1544 drummoyne au aus card xx672...
# 598 2019-09-03   -8.99           qe foodstores            camperdown   au
# 599 2019-09-03   -1.00  7-eleven 2118 camperdown ns aus card xx6725 va...
#
#                                          desc_features                google
# 0                                     hfm boronia park       Farmers' market
# 1                           charlotte cafe gladesville                  Cafe
# 2                         glen garry castle ho redfern                   Pub
# 3                         glen garry castle ho redfern                   Pub
# 4    transfer mr tryone kenhong jabez ja credit acc...                  None
# ..                                                 ...                   ...
# 595                    mr yeeros newtown flinders view  Fast food restaurant
# 596                                  eleven camperdown                  None
# 597                            coles express drummoyne                  None
# 598                           qe foodstores camperdown     Convenience store
# 599                                  eleven camperdown                  None
#
# [600 rows x 5 columns]

# %%
data.to_csv("scraper.csv")

# %%
scraper = pd.read_csv("scraper.csv", index_col=0)

# %%
def categorise(goog):
    shopping = ["market", "store", "shop"]
    food = ["restaurant", "cafe", "bakery", "takeaway"]
    beers = ["bar", "pub", "hotel"]
    health = ["dentist", "physiotherapist", "drug", "pharmacy", "pharmacist"]
    transport = ["petrol", "gas"]
    
    if pd.isnull(goog):
        return goog
    goog = goog.lower()

    for feat in health:
        if feat in goog:
            return "life/wellbeing"
    for feat in food:
        if feat in goog:
            return "food"
    for feat in beers:
        if feat in goog:
            return "beers"
    for feat in transport:
        if feat in goog:
            return "transport"
    for feat in shopping:
        if feat in goog:
            return "shopping"
    return None
    
    
scraper["category"] = [categorise(goog) for goog in scraper.google]
scraper = scraper.drop("google", axis=1)

# %%
labels = pd.read_csv("transactions_labelled.csv", index_col=0)
labels["desc_features"] = [clean(desc) for desc in labels.description]
labels

print(len(labels[["desc_features"]].drop_duplicates()))
print(len(labels[["desc_features", "category"]].drop_duplicates()))
labels
# Out:
# 250
# 253
#            date  amount                                        description  \
# 1    2020-06-26   50.00   transfer from margaret a jorgensen izzy tutoring
# 2    2020-06-08   50.00   transfer from margaret a jorgensen izzy tutoring
# 3    2020-05-25   50.00   transfer from margaret a jorgensen izzy tutoring
# 4    2020-05-18   50.00   transfer from margaret a jorgensen izzy tutoring
# 5    2020-05-03   50.00   transfer from margaret a jorgensen izzy tutoring
# ..          ...     ...                                                ...
# 595  2019-08-28   -6.10  uber   *trip sydney ns aus card xx6725 value d...
# 596  2019-08-28  -16.84  uber   *trip sydney ns aus card xx6725 value d...
# 597  2019-08-28  -10.00  sq *an dail camperdown au aus card xx6725 valu...
# 598  2019-08-27   -9.00           mcdonalds stanmore    stanmore     nswau
# 599  2019-08-27   -4.50  campos coffee newtown ns aus card xx6725 value...
#
#     category                              desc_features
# 1      wages  transfer margaret jorgensen izzy tutoring
# 2      wages  transfer margaret jorgensen izzy tutoring
# 3      wages  transfer margaret jorgensen izzy tutoring
# 4      wages  transfer margaret jorgensen izzy tutoring
# 5      wages  transfer margaret jorgensen izzy tutoring
# ..       ...                                        ...
# 595     uber                           uber trip sydney
# 596     uber                           uber trip sydney
# 597    beers                         sq dail camperdown
# 598     food                   mcdonalds stanmore nswau
# 599     food                      campos coffee newtown
#
# [573 rows x 5 columns]

# %%
# data["category"] = [None for _ in range(10)] + list(scraper.category[10::])
# data.merge(scraper.iloc[[1, 3, 5, 6]], left_index=True, right_index=True, how="left")
test = data.iloc[30:110]
print(len(test))
print(len(labels))

# print(len(test.merge(train, on=["desc_features", "amount"], how="left")))


lookup = pd.DataFrame(labels.drop(["date", 'amount','description'],axis=1).groupby(["desc_features"])["category"].unique().apply(','.join))
lookup = lookup.reset_index()
lookup = lookup[~lookup.category.str.contains(",")]
test.merge(lookup, on="desc_features", how="left", validate="many_to_one")
# Out:
# 80
# 573
#          date  amount                                        description  \
# 0  2020-06-25   -7.50  t famous berry don v berry  aus card xx6725 va...
# 1  2020-06-24  -16.00  haps hotels pty ltd gladesville ns aus card xx...
# 2  2020-06-24   -8.00  haps hotels pty ltd gladesville ns aus card xx...
# 3  2020-06-24   -7.40  haps hotels pty ltd gladesville ns aus card xx...
# 4  2020-06-24  -40.10  doitao thai boronia boronia park ns aus card x...
# ..        ...     ...                                                ...
# 75 2020-03-29   50.00   transfer from margaret a jorgensen izzy tutoring
# 76 2020-03-28  150.00    transfer from john holdsworth credit to account
# 77 2020-03-26   50.00       direct credit 128594 hartley brady 1hr maths
# 78 2020-03-26 -194.22  kogan.com chffd6y9 melbourne au aus card xx672...
# 79 2020-03-26  -13.00  alfred hotel mngmnt camperdown ns aus card xx6...
#
#                                 desc_features  category
# 0                                famous berry      food
# 1             haps hotels pty ltd gladesville     beers
# 2             haps hotels pty ltd gladesville     beers
# 3             haps hotels pty ltd gladesville     beers
# 4                    doitao thai boronia park       NaN
# ..                                        ...       ...
# 75  transfer margaret jorgensen izzy tutoring     wages
# 76    transfer john holdsworth credit account  transfer
# 77       direct credit hartley brady hr maths     wages
# 78                  kogan com chffd melbourne  shopping
# 79             alfred hotel mngmnt camperdown     beers
#
# [80 rows x 5 columns]
